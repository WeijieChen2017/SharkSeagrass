# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_x_y(x, y):
    fig, ax = plt.subplots(figsize=(5, 5), dpi=100)
    ax.scatter(x, y, s=3)
    ax.spines['left'].set_position('zero')
    ax.spines['bottom'].set_position('zero')
    ax.spines['top'].set_color('none')
    ax.spines['right'].set_color('none')
    ax.xaxis.tick_bottom()
    ax.yaxis.tick_left()
    ax.set_xlim(-1, 1)
    ax.set_ylim(-1, 1)
    fig.tight_layout()
    fig.show()

# %%
def plot_x_yList(x, yList):
    fig, ax = plt.subplots(figsize=(5, 5), dpi=100)
    for y in yList:
        ax.scatter(x, y, s=3)
    ax.spines['left'].set_position('zero')
    ax.spines['bottom'].set_position('zero')
    ax.spines['top'].set_color('none')
    ax.spines['right'].set_color('none')
    ax.xaxis.tick_bottom()
    ax.yaxis.tick_left()
    ax.set_xlim(-1, 1)
    ax.set_ylim(-1, 1)
    fig.tight_layout()
    fig.show()

# %%
def ReLU(x, y):
    y[y<0] = 0
    return y

# %%
# x, wx+b, sigma(wx+b), sum(sigma(wx+b))

w = 1
b = -0.5

n_points = 2000
xmesh = np.asarray(range(1, n_points)) / 1000 - 1
y1 = w*xmesh+b
y1 = ReLU(xmesh, y1)

plot_x_y(xmesh, y1)
# Out:
# /var/folders/vl/vvj01f7x49v3377g6kwlgk600000gq/T/ipykernel_7669/3619899771.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# x, wx+b, sigma(wx+b), sum(sigma(wx+b))
param_pairs = [
    [1, -0.5],
    # [1, 0.5],
    [1, -0.25],
    # [1, 0.25]
]


n_points = 2000
xmesh = np.asarray(range(1, n_points)) / 1000 - 1
yList = []
for w, b in param_pairs:
    y = w*xmesh+b
    y = ReLU(xmesh, y)
    yList.append(y)

plot_x_yList(xmesh, yList)
# Out:
# /var/folders/vl/vvj01f7x49v3377g6kwlgk600000gq/T/ipykernel_7669/1183390721.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# x, wx+b, sigma(wx+b), sum(sigma(wx+b))
param_pairs = [
    [[1, -0.25],[1, -0.5]],
    [[1, -0.5], [1, -0.75]],
]


n_points = 2000
xmesh = np.asarray(range(1, n_points)) / 1000 - 1
yList = []
for p1, p2 in param_pairs:
    w1, b1 = p1
    w2, b2 = p2
    y1 = w1*xmesh+b1
    y1 = ReLU(xmesh, y1)
    y2 = w2*xmesh+b2
    y2 = ReLU(xmesh, y2)
    yList.append(y1-y2)


plot_x_yList(xmesh, yList)
# Out:
# /var/folders/vl/vvj01f7x49v3377g6kwlgk600000gq/T/ipykernel_7669/1183390721.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# x, wx+b, sigma(wx+b), sum(sigma(wx+b))
param_pairs = [
    [[[1, -0.25],[1, -0.5]], [[1, -0.5], [1, -0.75]]],
]


n_points = 2000
xmesh = np.asarray(range(1, n_points)) / 1000 - 1
yList = []
for s1, s2 in param_pairs:
    p1, p2 = s1
    w1, b1 = p1
    w2, b2 = p2
    y1 = w1*xmesh+b1
    y1 = ReLU(xmesh, y1)
    y2 = w2*xmesh+b2
    y2 = ReLU(xmesh, y2)
    z1 = y1-y2

    p1, p2 = s2
    w1, b1 = p1
    w2, b2 = p2
    y1 = w1*xmesh+b1
    y1 = ReLU(xmesh, y1)
    y2 = w2*xmesh+b2
    y2 = ReLU(xmesh, y2)
    z2 = y1-y2
    
    yList.append(z1-z2)


plot_x_yList(xmesh, yList)
# Out:
# /var/folders/vl/vvj01f7x49v3377g6kwlgk600000gq/T/ipykernel_7669/1183390721.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Out:
# (8, 3, 120, 64)

# %%
filepath = "03-48-10_x_noisy.npy"

import numpy as np

data = np.load(filepath)
print(data.shape)

import matplotlib.pyplot as plt

# plot 8 images
fig = plt.subplots(2, 8, figsize=(16, 2))
for i in range(8):
    img = data[i]
    plt.subplot(2, 8, i+1)
    plt.hist(img.flatten(), bins=100)

    plt.subplot(2, 8, i+9)
    img = img / 3 # -1 to 1
    img = img + 1
    img = img / 2
    # change the img from c, w, h to w, h, c
    img = np.transpose(img, (1, 2, 0))
    img = np.rot90(img, 1)
    plt.imshow(img)

plt.show()
# Out:
# (8, 3, 64, 64)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.03829795..1.0615405].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.058800697..1.001276].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.06982377..1.036901].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02725327..1.0239604].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.021265298..1.0138073].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.055296272..1.0503976].
# ...

# %%
filepath = "03-58-54_x_start.npy"

import numpy as np

data = np.load(filepath)
print(data.shape)

import matplotlib.pyplot as plt

# plot 8 images
fig = plt.subplots(2, 8, figsize=(16, 4))
for i in range(8):
    img = data[i]
    plt.subplot(2, 8, i+1)
    plt.hist(img.flatten(), bins=100)

    plt.subplot(2, 8, i+9)
    img = img / 3 # -1 to 1
    img = img + 1
    img = img / 2
    # change the img from c, w, h to w, h, c
    img = np.transpose(img, (1, 2, 0))
    img = np.rot90(img, 1)
    plt.imshow(img)

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.028805494..1.0287228].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.047540158..1.008987].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010222584..1.0642618].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.054019034..0.9911411].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.04012084..0.9986671].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.04729116..1.0125287].
# (8, 3, 64, 64)
# ...

# %%
filepath = "encoded_c.npy"

import numpy as np

data = np.load(filepath)
print(data.shape)
# Out:
# (1, 3, 96, 256)

# %%
import matplotlib.pyplot as plt

plt.hist(np.ravel(data), bins=100)
print(np.mean(data), np.std(data))
# Out:
# 0.0783914 0.6217024

# %%
import torch

def extract_into_tensor(a, t, x_shape):
    b, *_ = t.shape
    out = a.gather(-1, t)
    return out.reshape(b, *((1,) * (len(x_shape) - 1)))

def q_sample(self, x_start, t, noise=None):
    noise = torch.randn_like(x_start)
    return (extract_into_tensor(self.sqrt_alphas_cumprod, t, x_start.shape) * x_start +
            extract_into_tensor(self.sqrt_one_minus_alphas_cumprod, t, x_start.shape) * noise)

# %%
vq_weights = "../../f4_vq_weights.npy"
import numpy as np

vq_weights = np.load(vq_weights)
print(vq_weights.shape)
# Out:
# (8192, 3)

# %%
import matplotlib.pyplot as plt

plt.hist(np.ravel(vq_weights), bins=100)
plt.yscale("log")
print(np.mean(vq_weights), np.std(data))
# Out:
# 0.03859937 0.6217024

# %%
path = "../../inpaint_encoded_c.npy"
import numpy as np
data = np.load(path)

import matplotlib.pyplot as plt

plt.hist(np.ravel(data), bins=100)
plt.yscale("log")
print(np.mean(data), np.std(data))
# Out:
# 0.030802593 1.1302459

# %%
path = "../../diffusion_ldm_vanilla_scaling_c_no_xT_test.npy"
import numpy as np
data = np.load(path)
print(data.shape)
data = data / 2 + 0.5

import matplotlib.pyplot as plt

plt.hist(np.ravel(data), bins=100)
plt.yscale("log")
print(np.mean(data), np.std(data))
# Out:
# (256, 256, 3)
# 0.74603444 0.108235605

# %%
# data = data / 2 + 0.5
plt.imshow(data[:, :, 1], cmap="gray")

# %%
plt.hist(np.ravel(data[:, :, 1]))
# Out:
# (array([1.3000e+01, 2.5900e+02, 3.8200e+03, 6.7530e+03, 8.3140e+03,
#         1.4916e+04, 2.2603e+04, 7.5570e+03, 1.2290e+03, 7.2000e+01]),
#  array([0.07497497, 0.15049085, 0.22600673, 0.30152261, 0.37703851,
#         0.45255437, 0.52807027, 0.60358614, 0.679102  , 0.75461793,
#         0.8301338 ]),
#  <BarContainer object of 10 artists>)

# %%
path = "../../diffusion_ldm_vanilla_scaling_cxT_test.npy"
import numpy as np
data = np.load(path)
print(data.shape)

import matplotlib.pyplot as plt

plt.hist(np.ravel(data), bins=100)
plt.yscale("log")
print(np.mean(data), np.std(data))
# Out:
# (256, 256, 3)
# 1.10338 0.09628785

# %%
data = data / 2
plt.imshow(data[:, :, 1], cmap="gray")

# %%
path = "../../diffusion_ldm_vanilla_scaling_cno_xT_new.npy"
import numpy as np
data = np.load(path)
print(data.shape)

import matplotlib.pyplot as plt

plt.hist(np.ravel(data), bins=100)
plt.yscale("log")
print(np.mean(data), np.std(data))
# data[data>1] = 1
# Out:
# (256, 256, 3)
# 0.492069 0.21647121

# %%
# data = data / 2
plt.imshow(data)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.2956063..0.9874088].
